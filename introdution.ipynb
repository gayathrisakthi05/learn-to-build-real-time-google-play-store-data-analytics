# %%
import pandas as pd
data=pd.read_csv('heart-disease.csv')
data
print(data)
print(data.head())
data.head()
print(data.tail())
data.tail()
data.info()
print(data.isnull().sum())
import numpy as np
df=pd.read_csv('Global EV Data 2024.csv')
print(df.isnull().sum())
df.info()
#Replace NaN values with meab for 'chol' column
data['chol']=data['chol'].replace(np.nan,data['chol'].mean())
#Import matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
#Import plotly express
import plotly.express as px
#Create sample data arrays
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10]) 
#Plot the points
plt.plot(xpoints,ypoints)
plt.show()
#Generate random normal distribution
x=np.random.normal(170,10,250)
print(x)
#Create histogram
plt.hist(x)
plt.show()
#Create distribution plot
sns.distplot([0,1,2,3,4,5])
plt.show()
#Import train_test_split and other skle
from sklearn.model_selection import train_test_split
from  sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error,r2_score
#Split the data
import numpy as np
from sklearn.model_selection import train_test_split

# Create sample dataset
X = np.random.normal(170, 10, 250).reshape(-1, 1)  # Features must be 2D
y = np.random.randint(0, 2, 250)  # Example target (binary classification)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

print("Training shape:", X_train.shape)
print("Testing shape:", X_test.shape)

 
# Import NLTK
import nltk
nltk.download('vader_lexicon')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...
